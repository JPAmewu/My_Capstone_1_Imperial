# %% [markdown]
# # Week 03 — Function 06
#
# Focused review reconstructed from starter data plus the immutable ledger. Confirmed cumulative evidence is available through Week 3.
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [GP model configuration](#gp-model-configuration)
# 9. [GP-UCB values](#gp-ucb-values)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# Focused review of one black-box function within the corresponding weekly optimisation round.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the available evidence, inspect the observed search history, review diagnostics, and connect the function-level result to the canonical weekly recommendation.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Inputs and returned outputs are reconstructed by the imported analysis module from repository-preserved evidence. Missing returns are not imputed.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup
#
# Locate the repository, import the function-specific analysis routine, and initialise plotting dependencies.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_03'/'Function_06'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_03_function_06 import analyse

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation
#
# Run the analysis and expose the persisted validation summary before interpreting results.

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 3,
#  'function': 6,
#  'dimensions': 5,
#  'starter_observations': 20,
#  'recorded_pairs': 3,
#  'total_verified_observations': 23,
#  'best_query': 1,
#  'best_input': [0.7281861047460138,
#   0.1546925696237983,
#   0.7325516687239811,
#   0.6939965090690888,
#   0.056401310518258585],
#  'best_output': -0.7142649478202404,
#  'latest_verified_query': 23,
#  'latest_verified_input': [0.49507, 0.097152, 0.672921, 7e-06, 0.351268],
#  'latest_verified_output': -1.339542402620705,
#  'latest_improves_previous_best': False,
#  'minimum_output': -2.5711696316081234,
#  'mean_output': -1.4468529075487313,
#  'standard_deviation': 0.44236924309255704,
#  'evidence_gap': 'Confirmed cumulative evidence is available through Week 3.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.'}

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# Inspect the complete observation table in query order for within-function descriptive review.

# %%
observations
# Out:
#     query  evidence        x1        x2        x3        x4        x5  \
# 0       1   starter  0.728186  0.154693  0.732552  0.693997  0.056401
# 1       2   starter  0.242384  0.844100  0.577809  0.679021  0.501953
# 2       3   starter  0.729523  0.748106  0.679775  0.356552  0.671054
# 3       4   starter  0.770620  0.114404  0.046780  0.648324  0.273549
# 4       5   starter  0.618812  0.331802  0.187288  0.756238  0.328835
# 5       6   starter  0.784958  0.910682  0.708120  0.959225  0.004911
# 6       7   starter  0.145111  0.896685  0.896322  0.726272  0.236272
# 7       8   starter  0.945069  0.288459  0.978806  0.961656  0.598016
# 8       9   starter  0.125720  0.862725  0.028544  0.246605  0.751206
# 9      10   starter  0.757594  0.355831  0.016523  0.434207  0.112433
# 10     11   starter  0.536797  0.308781  0.411879  0.388225  0.522528
# 11     12   starter  0.957740  0.235669  0.099146  0.156806  0.071317
# 12     13   starter  0.629308  0.803484  0.811408  0.045613  0.110624
# 13     14   starter  0.021735  0.428084  0.835939  0.489489  0.511082
# 14     15   starter  0.439344  0.698924  0.426820  0.109476  0.877888
# 15     16   starter  0.258906  0.793678  0.642114  0.196673  0.593103
# 16     17   starter  0.432166  0.715618  0.341819  0.705000  0.614962
# 17     18   starter  0.782880  0.536336  0.443284  0.859700  0.010326
# 18     19   starter  0.921776  0.931871  0.414876  0.595057  0.735626
# 19     20   starter  0.126679  0.291470  0.064528  0.680515  0.892819
# 20     21  recorded  0.728186  0.154693  0.732552  0.693997  0.564013
# 21     22  recorded  0.433654  0.486678  0.282753  0.972905  0.323321
# 22     23  recorded  0.495070  0.097152  0.672921  0.000007  0.351268
#
#     objective
# 0   -0.714265
# 1   -1.209955
# 2   -1.672200
# 3   -1.536058
# 4   -0.829237
# 5   -1.247049
# 6   -1.233786
# 7   -1.694343
# 8   -2.571170
# 9   -1.309116
# 10  -1.144785
# 11  -1.912677
# 12  -1.622839
# 13  -1.356682
# 14  -2.018425
# 15  -1.702558
# 16  -1.294247
# 17  -0.935757
# 18  -2.155768
# 19  -1.746882
# 20  -1.152035
# 21  -0.878241
# 22  -1.339542

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Display the function-level diagnostic figure generated from the validated observations.

# %%
figure

# %% [markdown]
# <a id="gp-model-configuration"></a>
# ## 8. GP model configuration
#
# The fitted model and acquisition configuration for this round are defined in the canonical Week 3 notebook `Week_3_Capstone.ipynb`.

# %% [markdown]
# <a id="gp-ucb-values"></a>
# ## 9. GP-UCB values
#
# The exact proposal, predictive uncertainty, and acquisition values—where applicable—are reported in the canonical Week 3 notebook. This focused notebook does not duplicate or relabel proposal-only evidence.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks
#
# Confirm observation counts, dimensional bounds, finite outputs, and function-level integrity.

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 03 Function 06 checks passed.')
# Out:
# All Week 03 Function 06 checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# Use this focused review alongside the canonical Week 3 notebook for the complete cross-function decision workflow and next-query recommendation.

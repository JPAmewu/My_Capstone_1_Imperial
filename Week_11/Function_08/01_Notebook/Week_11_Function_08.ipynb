# %% [markdown]
# # Week 11 — Function 08
#
# Focused review reconstructed from starter data plus the immutable ledger. Confirmed cumulative evidence is available through Week 11.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_11'/'Function_08'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_11_function_08 import analyse

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 11,
#  'function': 8,
#  'dimensions': 8,
#  'starter_observations': 40,
#  'recorded_pairs': 11,
#  'total_verified_observations': 51,
#  'best_query': 42,
#  'best_input': [0.16316,
#   0.184786,
#   0.152644,
#   0.083802,
#   0.999322,
#   0.544113,
#   0.184124,
#   0.123846],
#  'best_output': 9.9399041910574,
#  'latest_verified_query': 51,
#  'latest_verified_input': [0.234325,
#   0.196964,
#   0.387716,
#   0.46245,
#   0.845967,
#   0.154645,
#   0.549698,
#   0.111557],
#  'latest_verified_output': 9.2760687615836,
#  'latest_improves_previous_best': False,
#  'minimum_output': 5.5921933895401965,
#  'mean_output': 8.121828651202591,
#  'standard_deviation': 1.0422845392751205,
#  'evidence_gap': 'Confirmed cumulative evidence is available through Week 11.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.',
#  'archive_integrity': 'Original repository Week 11 arrays remain quarantined; analysis uses independently recovered pairs from the canonical ledger.'}

# %%
observations
# Out:
#     query  evidence        x1        x2        x3        x4        x5  \
# 0       1   starter  0.604994  0.292215  0.908453  0.355506  0.201669
# 1       2   starter  0.178007  0.566223  0.994862  0.210325  0.320153
# 2       3   starter  0.009077  0.811626  0.520520  0.075687  0.265112
# 3       4   starter  0.506028  0.653730  0.363411  0.177981  0.093728
# 4       5   starter  0.359909  0.249076  0.495997  0.709215  0.114987
# 5       6   starter  0.778818  0.003419  0.337983  0.519528  0.820907
# 6       7   starter  0.908649  0.062250  0.238260  0.766604  0.132336
# 7       8   starter  0.586371  0.880736  0.745021  0.546035  0.009649
# 8       9   starter  0.761137  0.854672  0.382124  0.337352  0.689708
# 9      10   starter  0.984933  0.699506  0.998885  0.180148  0.580143
# 10     11   starter  0.112071  0.437736  0.596599  0.592776  0.226982
# 11     12   starter  0.791888  0.576191  0.694528  0.283424  0.136755
# 12     13   starter  0.143550  0.937415  0.232325  0.009043  0.414579
# 13     14   starter  0.769917  0.458759  0.559000  0.694604  0.503199
# 14     15   starter  0.056447  0.065956  0.022929  0.038786  0.403935
# 15     16   starter  0.862437  0.482734  0.281869  0.544102  0.887490
# 3   0.197425  0.755827  0.292472   8.284008
# 4   0.289207  0.557295  0.593882   8.606117
# 5   0.537247  0.551347  0.660032   8.541748
# 6   0.990244  0.688068  0.742496   7.327435
# 7   0.748992  0.230907  0.097916   7.299872
# 8   0.309853  0.631380  0.041956   7.957875
# 9   0.231087  0.490827  0.313683   5.592193
# 10  0.410105  0.921238  0.674753   7.854541
# 11  0.279162  0.842767  0.625328   6.791986
# 12  0.409325  0.553779  0.205841   8.976554
# 13  0.728346  0.784254  0.663131   7.379083
# 14  0.801055  0.488307  0.893085   9.598482
# 15  0.382655  0.601902  0.476462   8.159983
# 16  0.088460  0.410153  0.195724   7.131624
# 17  0.445117  0.975180  0.374340   6.767963
# 18  0.287907  0.435010  0.364200   7.433744
# 19  0.158563  0.591030  0.077953   9.013075
# 20  0.386323  0.748972  0.988755   7.310894
# 21  0.282766  0.911078  0.472398   5.841067
# 22  0.875172  0.510560  0.728611   9.141639
# 23  0.245548  0.762483  0.732153   8.817558
# 24  0.030842  0.803255  0.595898   6.451943
# 25  0.022113  0.601483  0.524885   8.830745
# 26  0.654567  0.276241  0.295518   9.344274
# 27  0.535183  0.714743  0.960094   6.887846
# 28  0.937376  0.866508  0.127902   8.042213
# 29  0.132646  0.035909  0.446838   7.692368
# 30  0.480873  0.237647  0.768632   7.923759
# 31  0.906706  0.108231  0.525348   8.421759
# 32  0.783777  0.254495  0.871146   8.278062
# 33  0.520259  0.811040  0.103360   7.113457
# 34  0.905238  0.458875  0.560918   6.402588
# 35  0.622439  0.928974  0.112536   8.472936
# 36  0.210299  0.167546  0.963590   7.977685
# 37  0.252259  0.765670  0.890549   7.460872
# 38  0.706650  0.992914  0.381734   7.436594
# 39  0.244341  0.163825  0.715962   9.183005
# 40  0.230729  0.108688  0.352588   9.815709
# 41  0.544113  0.184124  0.123846   9.939904
# 42  0.217060  0.011239  0.447691   8.963604
# 43  0.260297  0.411421  0.904740   9.254064
# 44  0.716713  0.030436  0.083412   9.138609
# 45  0.965550  0.368459  0.301774   8.557034
# 46  0.887722  0.724982  0.315234   8.563639
# 47  0.106613  0.229839  0.008464   9.020091
# 48  0.249315  0.054463  0.073967   9.699892
# 49  0.070794  0.119397  0.111488   9.373668
# 50  0.154645  0.549698  0.111557   9.276069

# %%
figure

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 11 Function 08 checks passed.')
# Out:
# All Week 11 Function 08 checks passed.

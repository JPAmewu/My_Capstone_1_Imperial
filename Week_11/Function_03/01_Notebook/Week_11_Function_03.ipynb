# %% [markdown]
# # Week 11 — Function 03
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [Model and acquisition](#model-acquisition)
# 9. [Week 11 proposal](#week-11-proposal)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused review mirrors the canonical Week 11 methodology for Function 03, with Weeks 1–10 observed and Week 11 proposed only.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the 3-dimensional evidence, assess the latest returned point, and reproduce the recorded GP-UCB proposal without look-ahead.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Starter arrays come from `Week_01/Function_nn/03_Data`; exact returned pairs come from `Results/query_output_ledger.csv`. The Week 11 return is excluded because it was unknown when the proposal was selected.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT=Path.cwd().resolve()
for candidate in (ROOT,*ROOT.parents):
    if (candidate/'Week_11'/'Function_03').is_dir(): ROOT=candidate; break
else: raise FileNotFoundError('Could not locate repository root')
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
from Code.historical_function_review import analyse_historical_function

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation

# %%
observations, summary, proposal, diagnostic_figure = analyse_historical_function(11, 3, ROOT)
input_columns=[f'x{i}' for i in range(1,4)]
inputs=observations[input_columns].to_numpy(float)
outputs=observations['objective'].to_numpy(float)
assert inputs.shape==(25,3) and outputs.shape==(25,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs>=0)&(inputs<=1))
observations
# Out:
#     query  evidence        x1        x2        x3  objective
# 0       1   starter  0.171525  0.343917  0.248737  -0.112122
# 1       2   starter  0.242114  0.644074  0.272433  -0.087963
# 2       3   starter  0.534906  0.398501  0.173389  -0.111415
# 3       4   starter  0.492581  0.611593  0.340176  -0.034835
# 4       5   starter  0.134622  0.219917  0.458206  -0.048008
# 5       6   starter  0.345523  0.941360  0.269363  -0.110621
# 6       7   starter  0.151837  0.439991  0.990882  -0.398926
# 7       8   starter  0.645503  0.397143  0.919771  -0.113869
# 8       9   starter  0.746912  0.284196  0.226300  -0.131461
# 9      10   starter  0.170477  0.697032  0.149169  -0.094190
# 10     11   starter  0.220549  0.297825  0.343555  -0.046947
# 11     12   starter  0.666014  0.671985  0.246295  -0.105965
# 12     13   starter  0.046809  0.231360  0.770618  -0.118048
# 13     14   starter  0.600097  0.725136  0.066089  -0.036378
# 14     15   starter  0.965995  0.861120  0.566829  -0.056758
# 15     16  recorded  0.444444  0.666666  0.333333  -0.040908
# 16     17  recorded  0.657452  0.998464  0.817253  -0.089875
# 17     18  recorded  0.670026  0.057881  0.658241  -0.183239
# 18     19  recorded  0.650132  0.218327  0.110542  -0.082513
# 19     20  recorded  0.522711  0.090769  0.451242  -0.057397
# 20     21  recorded  0.418776  0.420613  0.695421  -0.117005
# 21     22  recorded  0.427731  0.669810  0.343678  -0.047183
# 22     23  recorded  0.457347  0.664022  0.295993  -0.077413
# 23     24  recorded  0.449035  0.664262  0.290384  -0.081893
# 24     25  recorded  0.447317  0.658930  0.324854  -0.046339

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# All comparisons are descriptive and within-function; no causal, global-optimum, or cross-function ranking claim is made.

# %%
pd.Series({k:v for k,v in summary.items() if k!='proposal'}, name='verified evidence')
# Out:
# week                                                                            11
# function                                                                         3
# dimensions                                                                       3
# starter_observations                                                            15
# recorded_pairs                                                                  10
# total_verified_observations                                                     25
# best_query                                                                       4
# best_input                       [0.49258141463713434, 0.6115931882759961, 0.34...
# best_output                                                              -0.034835
# latest_verified_query                                                           25
# latest_verified_input                                [0.447317, 0.65893, 0.324854]
# latest_verified_output                                                   -0.046339
# latest_improves_previous_best                                                False
# minimum_output                                                           -0.398926
# mean_output                                                              -0.097251
# standard_deviation                                                        0.071106
# evidence_gap                     Confirmed observed evidence is available throu...
# interpretation                   Within-function descriptive evidence; no causa...
# archive_integrity                Original repository Week 11 arrays remain quar...
# evidence_boundary                      Weeks 1-10 observed; Week 11 proposed only.
# Name: verified evidence, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Orange markers are returned Weeks 1–10 observations; the star is the verified incumbent. The Week 11 proposal is deliberately absent.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="model-acquisition"></a>
# ## 8. Model and acquisition
#
# Method: **GP-UCB**. This adaptive policy is a heuristic chosen from the evidence available at the decision boundary; it is not a statistically controlled acquisition comparison.

# %% [markdown]
# <a id="week-11-proposal"></a>
# ## 9. Week 11 proposal
#
# Proposed only: `[0.450034, 0.667941, 0.342989]`. Decision record: Chosen using evidence through Week 10, before the Week 11 return.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks

# %%
candidate=np.asarray(proposal['query'],dtype=float)
assert proposal['status']=='proposed_only'
assert candidate.shape==(3,) and np.all((candidate>=0)&(candidate<=0.999999))
duplicate=bool(np.any(np.all(np.isclose(inputs,candidate,rtol=0,atol=5e-7),axis=1)))
assert duplicate==proposal['duplicates_observed_evidence']
assert summary['recorded_pairs']==10
portal='-'.join(f'{value:.6f}' for value in candidate)
assert all(len(part.split('.')[-1])==6 for part in portal.split('-'))
print('Function 03 Week 11 checks passed:', portal, 'duplicate:', duplicate)
# Out:
# Function 03 Week 11 checks passed: 0.450034-0.667941-0.342989 duplicate: False

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The evidence boundary is locked at 25 verified observations. The Week 11 proposal remains unobserved until its authoritative return is appended at the next checkpoint.

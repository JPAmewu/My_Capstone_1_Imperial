# %% [markdown]
# # Week 04 — Function 04
#
# Focused review reconstructed from starter data plus the immutable ledger. Confirmed cumulative evidence is available through Week 4.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_04'/'Function_04'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_04_function_04 import analyse

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 4,
#  'function': 4,
#  'dimensions': 4,
#  'starter_observations': 30,
#  'recorded_pairs': 4,
#  'total_verified_observations': 34,
#  'best_query': 33,
#  'best_input': [0.394519, 0.361122, 0.256803, 0.461856],
#  'best_output': -1.9810750402526334,
#  'latest_verified_query': 34,
#  'latest_verified_input': [0.715715, 0.504442, 0.275065, 0.552962],
#  'latest_verified_output': -9.312811809021998,
#  'latest_improves_previous_best': False,
#  'minimum_output': -32.625660215962455,
#  'mean_output': -16.732775949274792,
#  'standard_deviation': 7.759375836481064,
#  'evidence_gap': 'Confirmed cumulative evidence is available through Week 4.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.'}

# %%
observations
# Out:
#     query  evidence        x1        x2        x3        x4  objective
# 0       1   starter  0.896981  0.725628  0.175404  0.701694 -22.108288
# 1       2   starter  0.889356  0.499588  0.539269  0.508783 -14.601397
# 2       3   starter  0.250946  0.033693  0.145380  0.494932 -11.699932
# 3       4   starter  0.346962  0.006250  0.760564  0.613024 -16.053765
# 4       5   starter  0.124871  0.129770  0.384400  0.287076 -10.069633
# 5       6   starter  0.801303  0.500231  0.706645  0.195103 -15.487083
# 6       7   starter  0.247708  0.060445  0.042186  0.441324 -12.681685
# 7       8   starter  0.746702  0.757092  0.369353  0.206566 -16.026400
# 8       9   starter  0.400665  0.072574  0.886768  0.243842 -17.049235
# 9      10   starter  0.626071  0.586751  0.438806  0.778858 -12.741766
# 10     11   starter  0.957135  0.597644  0.766114  0.776210 -27.316396
# 11     12   starter  0.732812  0.145250  0.476813  0.133366 -13.527649
# 12     13   starter  0.655115  0.072392  0.687152  0.081517 -16.679115
# 13     14   starter  0.219734  0.832031  0.482864  0.082569 -16.507159
# 14     15   starter  0.488594  0.211965  0.939178  0.376192 -17.817999
# 15     16   starter  0.167130  0.876555  0.217240  0.959801 -26.561821
# 16     17   starter  0.216911  0.166086  0.241372  0.770062 -12.758324
# 17     18   starter  0.387488  0.804532  0.751795  0.723827 -19.441558
# 18     19   starter  0.985622  0.666933  0.156783  0.856535 -28.903274
# 19     20   starter  0.037825  0.664853  0.161982  0.253924 -13.702747
# 20     21   starter  0.683486  0.902770  0.335420  0.999483 -29.427091
# 21     22   starter  0.170347  0.756959  0.276520  0.531231 -11.565742
# 22     23   starter  0.859657  0.919592  0.206139  0.097797 -26.857786
# 23     24   starter  0.282138  0.505987  0.530531  0.096302  -7.966775
# 24     25   starter  0.326076  0.472367  0.453192  0.105887  -6.702089
# 25     26   starter  0.948389  0.894513  0.851638  0.552196 -32.625660
# 26     27   starter  0.664955  0.046566  0.116777  0.793718 -19.989498
# 27     28   starter  0.577766  0.428772  0.425826  0.249007  -4.025542
# 28     29   starter  0.738613  0.482103  0.709366  0.503970 -13.122782
# 29     30   starter  0.854811  0.493965  0.735310  0.808092 -23.139428
# 30     31  recorded  0.555555  0.444444  0.222222  0.111111  -8.727516
# 31     32  recorded  0.006280  0.281840  0.932013  0.960202 -31.735358
# 32     33  recorded  0.394519  0.361122  0.256803  0.461856  -1.981075
# 33     34  recorded  0.715715  0.504442  0.275065  0.552962  -9.312812

# %%
figure

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 04 Function 04 checks passed.')
# Out:
# All Week 04 Function 04 checks passed.

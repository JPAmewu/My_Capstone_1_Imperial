# %% [markdown]
# # Week 07 — Function 06
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [Model and acquisition](#model-acquisition)
# 9. [Week 7 proposal](#week-7-proposal)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused review mirrors the canonical Week 7 methodology for Function 06, with Weeks 1–6 observed and Week 7 proposed only.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the 5-dimensional evidence, assess the latest returned point, and reproduce the recorded GP-UCB exploitation proposal without look-ahead.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Starter arrays come from `Week_01/Function_nn/03_Data`; exact returned pairs come from `Results/query_output_ledger.csv`. The Week 7 return is excluded because it was unknown when the proposal was selected.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT=Path.cwd().resolve()
for candidate in (ROOT,*ROOT.parents):
    if (candidate/'Week_07'/'Function_06').is_dir(): ROOT=candidate; break
else: raise FileNotFoundError('Could not locate repository root')
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
from Code.historical_function_review import analyse_historical_function

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation

# %%
observations, summary, proposal, diagnostic_figure = analyse_historical_function(7, 6, ROOT)
input_columns=[f'x{i}' for i in range(1,6)]
inputs=observations[input_columns].to_numpy(float)
outputs=observations['objective'].to_numpy(float)
assert inputs.shape==(26,5) and outputs.shape==(26,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs>=0)&(inputs<=1))
observations
# Out:
#     query  evidence        x1        x2        x3        x4        x5  \
# 0       1   starter  0.728186  0.154693  0.732552  0.693997  0.056401
# 1       2   starter  0.242384  0.844100  0.577809  0.679021  0.501953
# 2       3   starter  0.729523  0.748106  0.679775  0.356552  0.671054
# 3       4   starter  0.770620  0.114404  0.046780  0.648324  0.273549
# 4       5   starter  0.618812  0.331802  0.187288  0.756238  0.328835
# 5       6   starter  0.784958  0.910682  0.708120  0.959225  0.004911
# 6       7   starter  0.145111  0.896685  0.896322  0.726272  0.236272
# 7       8   starter  0.945069  0.288459  0.978806  0.961656  0.598016
# 8       9   starter  0.125720  0.862725  0.028544  0.246605  0.751206
# 9      10   starter  0.757594  0.355831  0.016523  0.434207  0.112433
# 10     11   starter  0.536797  0.308781  0.411879  0.388225  0.522528
# 11     12   starter  0.957740  0.235669  0.099146  0.156806  0.071317
# ...

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# All comparisons are descriptive and within-function; no causal, global-optimum, or cross-function ranking claim is made.

# %%
pd.Series({k:v for k,v in summary.items() if k!='proposal'}, name='verified evidence')
# Out:
# week                                                                             7
# function                                                                         6
# dimensions                                                                       5
# starter_observations                                                            20
# recorded_pairs                                                                   6
# total_verified_observations                                                     26
# best_query                                                                       1
# best_input                       [0.7281861047460138, 0.1546925696237983, 0.732...
# best_output                                                              -0.714265
# latest_verified_query                                                           26
# latest_verified_input             [0.78177, 0.192076, 0.805757, 0.695733, 0.56594]
# ...

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Orange markers are returned Weeks 1–6 observations; the star is the verified incumbent. The Week 7 proposal is deliberately absent.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="model-acquisition"></a>
# ## 8. Model and acquisition
#
# Method: **GP-UCB exploitation**. This adaptive policy is a heuristic chosen from the evidence available at the decision boundary; it is not a statistically controlled acquisition comparison.

# %% [markdown]
# <a id="week-7-proposal"></a>
# ## 9. Week 7 proposal
#
# Proposed only: `[0.68383, 0.035248, 0.777884, 0.740721, 0.62931]`. Decision record: Chosen using evidence through Week 6, before the Week 7 return.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks

# %%
candidate=np.asarray(proposal['query'],dtype=float)
assert proposal['status']=='proposed_only'
assert candidate.shape==(5,) and np.all((candidate>=0)&(candidate<=0.999999))
duplicate=bool(np.any(np.all(np.isclose(inputs,candidate,rtol=0,atol=5e-7),axis=1)))
assert duplicate==proposal['duplicates_observed_evidence']
assert summary['recorded_pairs']==6
portal='-'.join(f'{value:.6f}' for value in candidate)
assert all(len(part.split('.')[-1])==6 for part in portal.split('-'))
print('Function 06 Week 7 checks passed:', portal, 'duplicate:', duplicate)
# Out:
# Function 06 Week 7 checks passed: 0.683830-0.035248-0.777884-0.740721-0.629310 duplicate: False

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The evidence boundary is locked at 26 verified observations. The Week 7 proposal remains unobserved until its authoritative return is appended at the next checkpoint.

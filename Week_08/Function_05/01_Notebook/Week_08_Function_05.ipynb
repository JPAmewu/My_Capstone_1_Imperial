# %% [markdown]
# # Week 08 — Function 05
#
# Focused review of verified evidence. Weeks 3–5 and 7 returns are unavailable; no missing return is invented.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_08'/'Function_05'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_08_function_05 import analyse

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 8,
#  'function': 5,
#  'dimensions': 4,
#  'starter_observations': 20,
#  'recorded_pairs': 3,
#  'total_verified_observations': 23,
#  'best_query': 16,
#  'best_input': [0.22418902330288348,
#   0.8464804904862864,
#   0.8794841797090803,
#   0.8785156842249731],
#  'best_output': 1088.8596181962705,
#  'latest_verified_query': 23,
#  'latest_verified_input': [0.754614, 0.504566, 0.432986, 0.307039],
#  'latest_verified_output': 0.9401160531598542,
#  'latest_improves_previous_best': False,
#  'minimum_output': 0.1129397953712203,
#  'mean_output': 223.95066464707,
#  'standard_deviation': 346.93791488728476,
#  'evidence_gap': 'Weeks 3–5 and 7 returns are unavailable; the latest exact pair is Week 6.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.'}

# %%
observations
# Out:
#     query  evidence        x1        x2        x3        x4    objective
# 0       1   starter  0.191447  0.038193  0.607418  0.414584    64.443440
# 1       2   starter  0.758653  0.536518  0.656000  0.360342    18.301380
# 2       3   starter  0.438350  0.804340  0.210245  0.151295     0.112940
# 3       4   starter  0.706051  0.534192  0.264243  0.482088     4.210898
# 4       5   starter  0.836478  0.193610  0.663893  0.785649   258.370525
# 5       6   starter  0.683432  0.118663  0.829046  0.567577    78.434389
# 6       7   starter  0.553621  0.667350  0.323806  0.814870    57.571537
# 7       8   starter  0.352356  0.322242  0.116979  0.473113   109.571876
# 8       9   starter  0.153786  0.729382  0.422598  0.443074     8.847992
# 9      10   starter  0.463442  0.630025  0.107906  0.957644   233.223610
# 10     11   starter  0.677491  0.358510  0.479592  0.072880    24.423088
# 11     12   starter  0.583973  0.147243  0.348097  0.428615    64.420147
# 12     13   starter  0.306889  0.316878  0.622634  0.095399    63.476716
# 13     14   starter  0.511142  0.817957  0.728710  0.112354    79.729130
# 14     15   starter  0.438933  0.774092  0.378167  0.933696   355.806818
# 15     16   starter  0.224189  0.846480  0.879484  0.878516  1088.859618
# 16     17   starter  0.725262  0.479870  0.088947  0.759760    28.866752
# 17     18   starter  0.355482  0.639619  0.417618  0.122604    45.181570
# 18     19   starter  0.119879  0.862540  0.643331  0.849804   431.612757
# 19     20   starter  0.126885  0.153430  0.770162  0.190518     9.972332
# 20     21  recorded  0.224189  0.846480  0.879484  0.878515  1088.853511
# 21     22  recorded  0.255841  0.841692  0.888984  0.860260  1035.634146
# 22     23  recorded  0.754614  0.504566  0.432986  0.307039     0.940116

# %%
figure

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 08 Function 05 checks passed.')
# Out:
# All Week 08 Function 05 checks passed.

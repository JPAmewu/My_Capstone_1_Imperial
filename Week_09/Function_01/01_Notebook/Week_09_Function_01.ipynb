# %% [markdown]
# # Week 09 — Function 01
#
# Focused review reconstructed from starter data plus the immutable ledger. Confirmed cumulative evidence is available through Week 9.
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [GP model configuration](#gp-model-configuration)
# 9. [GP-UCB values](#gp-ucb-values)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# Focused review of one black-box function within the corresponding weekly optimisation round.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the available evidence, inspect the observed search history, review diagnostics, and connect the function-level result to the canonical weekly recommendation.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Inputs and returned outputs are reconstructed by the imported analysis module from repository-preserved evidence. Missing returns are not imputed.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup
#
# Locate the repository, import the function-specific analysis routine, and initialise plotting dependencies.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_09'/'Function_01'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_09_function_01 import analyse

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation
#
# Run the analysis and expose the persisted validation summary before interpreting results.

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 9,
#  'function': 1,
#  'dimensions': 2,
#  'starter_observations': 10,
#  'recorded_pairs': 9,
#  'total_verified_observations': 19,
#  'best_query': 3,
#  'best_input': [0.7310236309563586, 0.7329998764152272],
#  'best_output': 7.710875114502849e-16,
#  'latest_verified_query': 19,
#  'latest_verified_input': [0.42141, 0.935804],
#  'latest_verified_output': -3.089423814911752e-96,
#  'latest_improves_previous_best': False,
#  'minimum_output': -0.0036060626443634764,
#  'mean_output': -0.00018979277075593186,
#  'standard_deviation': 0.0008052225313304014,
#  'evidence_gap': 'Confirmed cumulative evidence is available through Week 9.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.'}

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# Inspect the complete observation table in query order for within-function descriptive review.

# %%
observations
# Out:
#     query  evidence        x1        x2      objective
# 0       1   starter  0.319404  0.762959   1.322677e-79
# 1       2   starter  0.574329  0.879898   1.033078e-46
# 2       3   starter  0.731024  0.733000   7.710875e-16
# 3       4   starter  0.840353  0.264732  3.341771e-124
# 4       5   starter  0.650114  0.681526  -3.606063e-03
# 5       6   starter  0.410437  0.147554  -2.159249e-54
# 6       7   starter  0.312691  0.078723  -2.089093e-91
# 7       8   starter  0.683418  0.861057   2.535001e-40
# 8       9   starter  0.082507  0.403488   3.606771e-81
# 9      10   starter  0.883890  0.582254   6.229856e-48
# 10     11  recorded  0.374540  0.950714 -1.560647e-117
# 11     12  recorded  0.536429  0.835362   1.674933e-36
# 12     13  recorded  0.614168  0.334143  -1.075594e-32
# 13     14  recorded  0.872626  0.321598 -2.466641e-107
# 14     15  recorded  0.897714  0.081699  7.651210e-239
# 15     16  recorded  0.222521  0.999673  6.131855e-211
# 16     17  recorded  0.350420  0.999543 -6.738616e-151
# 17     18  recorded  0.397837  0.919531  -1.772400e-96
# 18     19  recorded  0.421410  0.935804  -3.089424e-96

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Display the function-level diagnostic figure generated from the validated observations.

# %%
figure

# %% [markdown]
# <a id="gp-model-configuration"></a>
# ## 8. GP model configuration
#
# The fitted model and acquisition configuration for this round are defined in the canonical Week 9 notebook `Week_9_Capstone.ipynb`.

# %% [markdown]
# <a id="gp-ucb-values"></a>
# ## 9. GP-UCB values
#
# The exact proposal, predictive uncertainty, and acquisition values—where applicable—are reported in the canonical Week 9 notebook. This focused notebook does not duplicate or relabel proposal-only evidence.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks
#
# Confirm observation counts, dimensional bounds, finite outputs, and function-level integrity.

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 09 Function 01 checks passed.')
# Out:
# All Week 09 Function 01 checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# Use this focused review alongside the canonical Week 9 notebook for the complete cross-function decision workflow and next-query recommendation.

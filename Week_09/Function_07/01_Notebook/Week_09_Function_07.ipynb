# %% [markdown]
# # Week 09 — Function 07
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [Model and acquisition](#model-acquisition)
# 9. [Week 9 proposal](#week-9-proposal)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused review mirrors the canonical Week 9 methodology for Function 07, with Weeks 1–8 observed and Week 9 proposed only.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the 6-dimensional evidence, assess the latest returned point, and reproduce the recorded Expected Improvement proposal without look-ahead.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Starter arrays come from `Week_01/Function_nn/03_Data`; exact returned pairs come from `Results/query_output_ledger.csv`. The Week 9 return is excluded because it was unknown when the proposal was selected.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT=Path.cwd().resolve()
for candidate in (ROOT,*ROOT.parents):
    if (candidate/'Week_09'/'Function_07').is_dir(): ROOT=candidate; break
else: raise FileNotFoundError('Could not locate repository root')
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
from Code.historical_function_review import analyse_historical_function

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation

# %%
observations, summary, proposal, diagnostic_figure = analyse_historical_function(9, 7, ROOT)
input_columns=[f'x{i}' for i in range(1,7)]
inputs=observations[input_columns].to_numpy(float)
outputs=observations['objective'].to_numpy(float)
assert inputs.shape==(38,6) and outputs.shape==(38,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs>=0)&(inputs<=1))
observations
# Out:
#     query  evidence        x1        x2        x3        x4        x5  \
# 0       1   starter  0.272624  0.324495  0.897109  0.832951  0.154063
# 1       2   starter  0.543003  0.924694  0.341567  0.646486  0.718440
# 2       3   starter  0.090832  0.661529  0.065931  0.258577  0.963453
# 3       4   starter  0.118867  0.615055  0.905816  0.855300  0.413631
# 4       5   starter  0.630218  0.838097  0.680013  0.731895  0.526737
# 5       6   starter  0.764919  0.255883  0.609084  0.218079  0.322943
# 6       7   starter  0.057896  0.491672  0.247422  0.218118  0.420428
# 7       8   starter  0.195252  0.079227  0.554580  0.170567  0.014944
# 8       9   starter  0.642303  0.836875  0.021793  0.101488  0.683071
# 9      10   starter  0.789943  0.195545  0.575623  0.073659  0.259049
# 10     11   starter  0.528497  0.457424  0.360096  0.362046  0.816891
# 32  0.815792   2.149905
# 33  0.616114   1.208733
# 34  0.492629   0.190783
# 35  0.515646   1.611967
# 36  0.591179   0.899499
# 37  0.644030   0.846180

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# All comparisons are descriptive and within-function; no causal, global-optimum, or cross-function ranking claim is made.

# %%
pd.Series({k:v for k,v in summary.items() if k!='proposal'}, name='verified evidence')
# Out:
# week                                                                             9
# function                                                                         7
# dimensions                                                                       6
# starter_observations                                                            30
# recorded_pairs                                                                   8
# total_verified_observations                                                     38
# best_query                                                                      33
# best_input                       [0.143585, 0.302559, 0.571101, 0.194533, 0.395...
# best_output                                                               2.149905
# latest_verified_query                                                           38
# latest_verified_input            [0.016174, 0.558963, 0.348588, 0.050763, 0.417...
# latest_verified_output                                                     0.84618
# latest_improves_previous_best                                                False
# minimum_output                                                            0.002701
# mean_output                                                               0.390922
# standard_deviation                                                        0.508381
# evidence_gap                     Confirmed observed evidence is available throu...
# interpretation                   Within-function descriptive evidence; no causa...
# evidence_boundary                        Weeks 1-8 observed; Week 9 proposed only.
# Name: verified evidence, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Orange markers are returned Weeks 1–8 observations; the star is the verified incumbent. The Week 9 proposal is deliberately absent.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="model-acquisition"></a>
# ## 8. Model and acquisition
#
# Method: **Expected Improvement**. This adaptive policy is a heuristic chosen from the evidence available at the decision boundary; it is not a statistically controlled acquisition comparison.

# %% [markdown]
# <a id="week-9-proposal"></a>
# ## 9. Week 9 proposal
#
# Proposed only: `[0.018603, 0.530937, 0.376818, 0.094048, 0.443567, 0.614974]`. Decision record: Chosen using evidence through Week 8, before the Week 9 return.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks

# %%
candidate=np.asarray(proposal['query'],dtype=float)
assert proposal['status']=='proposed_only'
assert candidate.shape==(6,) and np.all((candidate>=0)&(candidate<=0.999999))
duplicate=bool(np.any(np.all(np.isclose(inputs,candidate,rtol=0,atol=5e-7),axis=1)))
assert duplicate==proposal['duplicates_observed_evidence']
assert summary['recorded_pairs']==8
portal='-'.join(f'{value:.6f}' for value in candidate)
assert all(len(part.split('.')[-1])==6 for part in portal.split('-'))
print('Function 07 Week 9 checks passed:', portal, 'duplicate:', duplicate)
# Out:
# Function 07 Week 9 checks passed: 0.018603-0.530937-0.376818-0.094048-0.443567-0.614974 duplicate: False

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The evidence boundary is locked at 38 verified observations. The Week 9 proposal remains unobserved until its authoritative return is appended at the next checkpoint.

# %% [markdown]
# # Week 02 — Function 01
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [Model and acquisition](#model-acquisition)
# 9. [Week 2 proposal](#week-2-proposal)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused notebook mirrors the canonical Week 2 main notebook for Function 01. It observes the starter data plus the returned Week 1 point and keeps the Week 2 query proposal separate.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the 2-dimensional cumulative evidence, assess the latest returned point within Function 01, and reproduce the Week 2 Bayesian Optimisation proposal without look-ahead.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Starter arrays come from `Week_01/Function_nn/03_Data`; the exact Week 1 query/return comes from the canonical ledger. The Week 2 return is excluded because it was unknown when this proposal was made.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT=Path.cwd().resolve()
for candidate in (ROOT,*ROOT.parents):
    if (candidate/'Week_02'/'Function_01').is_dir(): ROOT=candidate; break
else: raise FileNotFoundError('Could not locate repository root')
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
from Code.week_02_function_review import analyse_week_02_function

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation

# %%
observations, summary, proposal, diagnostic_figure = analyse_week_02_function(1, ROOT)
input_columns=[f'x{i}' for i in range(1,3)]
inputs=observations[input_columns].to_numpy(float)
outputs=observations['objective'].to_numpy(float)
assert inputs.shape==(11,2) and outputs.shape==(11,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs>=0)&(inputs<=1))
observations
# Out:
#     query  evidence        x1        x2      objective
# 0       1   starter  0.319404  0.762959   1.322677e-79
# 1       2   starter  0.574329  0.879898   1.033078e-46
# 2       3   starter  0.731024  0.733000   7.710875e-16
# 3       4   starter  0.840353  0.264732  3.341771e-124
# 4       5   starter  0.650114  0.681526  -3.606063e-03
# 5       6   starter  0.410437  0.147554  -2.159249e-54
# 6       7   starter  0.312691  0.078723  -2.089093e-91
# 7       8   starter  0.683418  0.861057   2.535001e-40
# 8       9   starter  0.082507  0.403488   3.606771e-81
# 9      10   starter  0.883890  0.582254   6.229856e-48
# 10     11  recorded  0.374540  0.950714 -1.560647e-117

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# All comparisons are within-function; no causal, global-optimum, or cross-function ranking claim is made.

# %%
pd.Series({k:v for k,v in summary.items() if k!='proposal'}, name='verified evidence')
# Out:
# week                                                                             2
# function                                                                         1
# dimensions                                                                       2
# starter_observations                                                            10
# recorded_pairs                                                                   1
# total_verified_observations                                                     11
# best_query                                                                       3
# best_input                                [0.7310236309563586, 0.7329998764152272]
# best_output                                                                    0.0
# latest_verified_query                                                           11
# latest_verified_input                                          [0.37454, 0.950714]
# latest_verified_output                                                        -0.0
# latest_improves_previous_best                                                False
# minimum_output                                                           -0.003606
# mean_output                                                              -0.000328
# standard_deviation                                                        0.001037
# evidence_gap                     Confirmed observed evidence is available throu...
# interpretation                   Within-function descriptive evidence; no causa...
# evidence_boundary                Week 1 starter data and Week 1 return observed...
# Name: verified evidence, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# The orange marker is the returned Week 1 observation and the star is the verified incumbent.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="model-acquisition"></a>
# ## 8. Model and acquisition
#
# Method: **Bayesian Optimisation**. For GP-UCB, `kappa=5.0` and a seeded 5,000-point candidate set reproduce the main notebook.

# %% [markdown]
# <a id="week-2-proposal"></a>
# ## 9. Week 2 proposal
#
# Proposed only: `[0.2696880845528554, 0.20624589334086108]`. This point is not included in `observations`.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks

# %%
candidate=np.asarray(proposal['query'],dtype=float)
assert proposal['status']=='proposed_only'
assert candidate.shape==(2,) and np.all((candidate>=0)&(candidate<=1))
assert not np.any(np.all(np.isclose(inputs,candidate,rtol=0,atol=1e-12),axis=1))
assert summary['total_verified_observations']==11
assert summary['recorded_pairs']==1
print('Function 01 Week 2 checks passed.')
# Out:
# Function 01 Week 2 checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The evidence boundary is locked at 11 verified observations. The Week 2 proposal remains unobserved until its authoritative return is appended at the next checkpoint.

# %% [markdown]
# # Week 02 — Function 03
#
# Focused review reconstructed from starter data plus the immutable ledger. Confirmed cumulative evidence is available through Week 2.
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [GP model configuration](#gp-model-configuration)
# 9. [GP-UCB values](#gp-ucb-values)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# Focused review of one black-box function within the corresponding weekly optimisation round.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the available evidence, inspect the observed search history, review diagnostics, and connect the function-level result to the canonical weekly recommendation.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Inputs and returned outputs are reconstructed by the imported analysis module from repository-preserved evidence. Missing returns are not imputed.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup
#
# Locate the repository, import the function-specific analysis routine, and initialise plotting dependencies.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_02'/'Function_03'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_02_function_03 import analyse

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation
#
# Run the analysis and expose the persisted validation summary before interpreting results.

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 2,
#  'function': 3,
#  'dimensions': 3,
#  'starter_observations': 15,
#  'recorded_pairs': 2,
#  'total_verified_observations': 17,
#  'best_query': 4,
#  'best_input': [0.49258141463713434, 0.6115931882759961, 0.3401763860035727],
#  'best_output': -0.034835313350078584,
#  'latest_verified_query': 17,
#  'latest_verified_input': [0.657452, 0.998464, 0.817253],
#  'latest_verified_output': -0.08987474979637637,
#  'latest_improves_previous_best': False,
#  'minimum_output': -0.3989255131463011,
#  'mean_output': -0.1022521758333652,
#  'standard_deviation': 0.08068042799774233,
#  'evidence_gap': 'Confirmed cumulative evidence is available through Week 2.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.'}

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# Inspect the complete observation table in query order for within-function descriptive review.

# %%
observations
# Out:
#     query  evidence        x1        x2        x3  objective
# 0       1   starter  0.171525  0.343917  0.248737  -0.112122
# 1       2   starter  0.242114  0.644074  0.272433  -0.087963
# 2       3   starter  0.534906  0.398501  0.173389  -0.111415
# 3       4   starter  0.492581  0.611593  0.340176  -0.034835
# 4       5   starter  0.134622  0.219917  0.458206  -0.048008
# 5       6   starter  0.345523  0.941360  0.269363  -0.110621
# 6       7   starter  0.151837  0.439991  0.990882  -0.398926
# 7       8   starter  0.645503  0.397143  0.919771  -0.113869
# 8       9   starter  0.746912  0.284196  0.226300  -0.131461
# 9      10   starter  0.170477  0.697032  0.149169  -0.094190
# 10     11   starter  0.220549  0.297825  0.343555  -0.046947
# 11     12   starter  0.666014  0.671985  0.246295  -0.105965
# 12     13   starter  0.046809  0.231360  0.770618  -0.118048
# 13     14   starter  0.600097  0.725136  0.066089  -0.036378
# 14     15   starter  0.965995  0.861120  0.566829  -0.056758
# 15     16  recorded  0.444444  0.666666  0.333333  -0.040908
# 16     17  recorded  0.657452  0.998464  0.817253  -0.089875

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Display the function-level diagnostic figure generated from the validated observations.

# %%
figure

# %% [markdown]
# <a id="gp-model-configuration"></a>
# ## 8. GP model configuration
#
# The fitted model and acquisition configuration for this round are defined in the canonical Week 2 notebook `Week_2_Capstone.ipynb`.

# %% [markdown]
# <a id="gp-ucb-values"></a>
# ## 9. GP-UCB values
#
# The exact proposal, predictive uncertainty, and acquisition values—where applicable—are reported in the canonical Week 2 notebook. This focused notebook does not duplicate or relabel proposal-only evidence.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks
#
# Confirm observation counts, dimensional bounds, finite outputs, and function-level integrity.

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 02 Function 03 checks passed.')
# Out:
# All Week 02 Function 03 checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# Use this focused review alongside the canonical Week 2 notebook for the complete cross-function decision workflow and next-query recommendation.

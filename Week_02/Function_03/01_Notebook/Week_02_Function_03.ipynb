# %% [markdown]
# # Week 02 — Function 03
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [Model and acquisition](#model-acquisition)
# 9. [Week 2 proposal](#week-2-proposal)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused notebook mirrors the canonical Week 2 main notebook for Function 03. It observes the starter data plus the returned Week 1 point and keeps the Week 2 query proposal separate.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the 3-dimensional cumulative evidence, assess the latest returned point within Function 03, and reproduce the Week 2 Bayesian Optimisation proposal without look-ahead.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Starter arrays come from `Week_01/Function_nn/03_Data`; the exact Week 1 query/return comes from the canonical ledger. The Week 2 return is excluded because it was unknown when this proposal was made.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT=Path.cwd().resolve()
for candidate in (ROOT,*ROOT.parents):
    if (candidate/'Week_02'/'Function_03').is_dir(): ROOT=candidate; break
else: raise FileNotFoundError('Could not locate repository root')
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
from Code.week_02_function_review import analyse_week_02_function

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation

# %%
observations, summary, proposal, diagnostic_figure = analyse_week_02_function(3, ROOT)
input_columns=[f'x{i}' for i in range(1,4)]
inputs=observations[input_columns].to_numpy(float)
outputs=observations['objective'].to_numpy(float)
assert inputs.shape==(16,3) and outputs.shape==(16,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs>=0)&(inputs<=1))
observations
# Out:
#     query  evidence        x1        x2        x3  objective
# 0       1   starter  0.171525  0.343917  0.248737  -0.112122
# 1       2   starter  0.242114  0.644074  0.272433  -0.087963
# 2       3   starter  0.534906  0.398501  0.173389  -0.111415
# 3       4   starter  0.492581  0.611593  0.340176  -0.034835
# 4       5   starter  0.134622  0.219917  0.458206  -0.048008
# 5       6   starter  0.345523  0.941360  0.269363  -0.110621
# 6       7   starter  0.151837  0.439991  0.990882  -0.398926
# 7       8   starter  0.645503  0.397143  0.919771  -0.113869
# 8       9   starter  0.746912  0.284196  0.226300  -0.131461
# 9      10   starter  0.170477  0.697032  0.149169  -0.094190
# 10     11   starter  0.220549  0.297825  0.343555  -0.046947
# 11     12   starter  0.666014  0.671985  0.246295  -0.105965
# 12     13   starter  0.046809  0.231360  0.770618  -0.118048
# 13     14   starter  0.600097  0.725136  0.066089  -0.036378
# 14     15   starter  0.965995  0.861120  0.566829  -0.056758
# 15     16  recorded  0.444444  0.666666  0.333333  -0.040908

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# All comparisons are within-function; no causal, global-optimum, or cross-function ranking claim is made.

# %%
pd.Series({k:v for k,v in summary.items() if k!='proposal'}, name='verified evidence')
# Out:
# week                                                                             2
# function                                                                         3
# dimensions                                                                       3
# starter_observations                                                            15
# recorded_pairs                                                                   1
# total_verified_observations                                                     16
# best_query                                                                       4
# best_input                       [0.49258141463713434, 0.6115931882759961, 0.34...
# best_output                                                              -0.034835
# latest_verified_query                                                           16
# latest_verified_input                               [0.444444, 0.666666, 0.333333]
# latest_verified_output                                                   -0.040908
# latest_improves_previous_best                                                False
# minimum_output                                                           -0.398926
# mean_output                                                              -0.103026
# standard_deviation                                                        0.083102
# evidence_gap                     Confirmed observed evidence is available throu...
# interpretation                   Within-function descriptive evidence; no causa...
# evidence_boundary                Week 1 starter data and Week 1 return observed...
# Name: verified evidence, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# The orange marker is the returned Week 1 observation and the star is the verified incumbent.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="model-acquisition"></a>
# ## 8. Model and acquisition
#
# Method: **Bayesian Optimisation**. For GP-UCB, `kappa=5.0` and a seeded 5,000-point candidate set reproduce the main notebook.

# %% [markdown]
# <a id="week-2-proposal"></a>
# ## 9. Week 2 proposal
#
# Proposed only: `[0.11964689800101047, 0.9810627348420401, 0.8346992440355415]`. This point is not included in `observations`.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks

# %%
candidate=np.asarray(proposal['query'],dtype=float)
assert proposal['status']=='proposed_only'
assert candidate.shape==(3,) and np.all((candidate>=0)&(candidate<=1))
assert not np.any(np.all(np.isclose(inputs,candidate,rtol=0,atol=1e-12),axis=1))
assert summary['total_verified_observations']==16
assert summary['recorded_pairs']==1
print('Function 03 Week 2 checks passed.')
# Out:
# Function 03 Week 2 checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The evidence boundary is locked at 16 verified observations. The Week 2 proposal remains unobserved until its authoritative return is appended at the next checkpoint.

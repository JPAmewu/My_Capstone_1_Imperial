# %% [markdown]
# <a href="https://colab.research.google.com/github/JPAmewu/My_Capstone_1_Imperial/blob/main/Week_1_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Colab is connected')
# Out:
# Colab is connected

# %%
import numpy as np
import pandas as pd
import sklearn

print('Numpy:', np.__version__)
print('Pandas:', pd.__version__)
print('Scikit-Learn:',sklearn.__version__)
# Out:
# Numpy: 2.0.2
# Pandas: 2.2.2
# Scikit-Learn: 1.6.1

# %%
import numpy as np

x = np.linspace(0, 1, 5)

print(x)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %% [markdown]
# #Imperial ML/AI Capstone Setup Check

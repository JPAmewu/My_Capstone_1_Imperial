# %% [markdown]
# # Week 13 — Function 02
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [Model and acquisition](#model-acquisition)
# 9. [Week 13 proposal](#week-13-proposal)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused review mirrors the canonical Week 13 methodology for Function 02, with Weeks 1–12 observed and Week 13 proposed only.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the 2-dimensional evidence, assess the latest returned point, and reproduce the recorded EI proposal without look-ahead.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# Starter arrays come from `Week_01/Function_nn/03_Data`; exact returned pairs come from `Results/query_output_ledger.csv`. The Week 13 return is excluded because it was unknown when the proposal was selected.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT=Path.cwd().resolve()
for candidate in (ROOT,*ROOT.parents):
    if (candidate/'Week_13'/'Function_02').is_dir(): ROOT=candidate; break
else: raise FileNotFoundError('Could not locate repository root')
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
from Code.historical_function_review import analyse_historical_function

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation

# %%
observations, summary, proposal, diagnostic_figure = analyse_historical_function(13, 2, ROOT)
input_columns=[f'x{i}' for i in range(1,3)]
inputs=observations[input_columns].to_numpy(float)
outputs=observations['objective'].to_numpy(float)
assert inputs.shape==(22,2) and outputs.shape==(22,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs>=0)&(inputs<=1))
observations
# Out:
#     query  evidence        x1        x2  objective
# 0       1   starter  0.665800  0.123969   0.538996
# 1       2   starter  0.877791  0.778628   0.420586
# 2       3   starter  0.142699  0.349005  -0.065624
# 3       4   starter  0.845275  0.711120   0.293993
# 4       5   starter  0.454647  0.290455   0.214965
# 5       6   starter  0.577713  0.771973   0.023106
# 6       7   starter  0.438166  0.685018   0.244619
# 7       8   starter  0.341750  0.028698   0.038749
# 8       9   starter  0.338648  0.213867  -0.013858
# 9      10   starter  0.702637  0.926564   0.611205
# 10     11  recorded  0.374540  0.950714  -0.031830
# 11     12  recorded  0.978752  0.932731   0.022667
# 12     13  recorded  0.000006  0.334143   0.048684
# 13     14  recorded  0.197553  0.808683   0.038775
# 14     15  recorded  0.555332  0.360931   0.220781
# 15     16  recorded  0.473151  0.950706   0.160532
# 16     17  recorded  0.009675  0.999881   0.048714
# 17     18  recorded  0.314242  0.973527   0.072764
# 18     19  recorded  0.995366  0.102732   0.049406
# 19     20  recorded  0.329121  0.997950   0.026788
# 20     21  recorded  0.384537  0.996119   0.065300
# 21     22  recorded  0.692505  0.619198   0.607382

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# All comparisons are descriptive and within-function; no causal, global-optimum, or cross-function ranking claim is made.

# %%
pd.Series({k:v for k,v in summary.items() if k!='proposal'}, name='verified evidence')
# Out:
# week                                                                            13
# function                                                                         2
# dimensions                                                                       2
# starter_observations                                                            10
# recorded_pairs                                                                  12
# total_verified_observations                                                     22
# best_query                                                                      10
# best_input                                [0.7026365569244406, 0.9265641975455574]
# best_output                                                               0.611205
# latest_verified_query                                                           22
# latest_verified_input                                         [0.692505, 0.619198]
# latest_verified_output                                                    0.607382
# latest_improves_previous_best                                                False
# minimum_output                                                           -0.065624
# mean_output                                                               0.165305
# standard_deviation                                                        0.202569
# evidence_gap                     Confirmed observed evidence is available throu...
# interpretation                   Within-function descriptive evidence; no causa...
# archive_integrity                Original repository Week 11 arrays remain quar...
# evidence_boundary                      Weeks 1-12 observed; Week 13 proposed only.
# Name: verified evidence, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Orange markers are returned Weeks 1–12 observations; the star is the verified incumbent. The Week 13 proposal is deliberately absent.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="model-acquisition"></a>
# ## 8. Model and acquisition
#
# Method: **EI**. This adaptive policy is a heuristic chosen from the evidence available at the decision boundary; it is not a statistically controlled acquisition comparison.

# %% [markdown]
# <a id="week-13-proposal"></a>
# ## 9. Week 13 proposal
#
# Proposed only: `[0.686305, 0.999999]`. Decision record: The strong Week 12 return supports balanced improvement around a promising region.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks

# %%
candidate=np.asarray(proposal['query'],dtype=float)
assert proposal['status']=='proposed_only'
assert candidate.shape==(2,) and np.all((candidate>=0)&(candidate<=0.999999))
duplicate=bool(np.any(np.all(np.isclose(inputs,candidate,rtol=0,atol=5e-7),axis=1)))
assert duplicate==proposal['duplicates_observed_evidence']
assert summary['recorded_pairs']==12
portal='-'.join(f'{value:.6f}' for value in candidate)
assert all(len(part.split('.')[-1])==6 for part in portal.split('-'))
print('Function 02 Week 13 checks passed:', portal, 'duplicate:', duplicate)
# Out:
# Function 02 Week 13 checks passed: 0.686305-0.999999 duplicate: False

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The evidence boundary is locked at 22 verified observations. The Week 13 proposal remains unobserved until its authoritative return is appended at the next checkpoint.

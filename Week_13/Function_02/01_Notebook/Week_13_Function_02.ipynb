# %% [markdown]
# # Week 13 — Function 02
#
# Focused review reconstructed from starter data plus the immutable ledger. No verified Week 12 or Week 13 return is present; confirmed evidence is carried forward through Week 11.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root=Path.cwd().resolve()
while not (repo_root/'Code').exists() and repo_root!=repo_root.parent: repo_root=repo_root.parent
function_root=repo_root/'Week_13'/'Function_02'
sys.path.insert(0,str(function_root/'02_Code'))
from analyse_week_13_function_02 import analyse

# %%
observations,summary,figure=analyse()
summary
# Out:
# {'week': 13,
#  'function': 2,
#  'dimensions': 2,
#  'starter_observations': 10,
#  'recorded_pairs': 11,
#  'total_verified_observations': 21,
#  'best_query': 10,
#  'best_input': [0.7026365569244406, 0.9265641975455574],
#  'best_output': 0.6112052157614438,
#  'latest_verified_query': 21,
#  'latest_verified_input': [0.384537, 0.996119],
#  'latest_verified_output': 0.06529972619341909,
#  'latest_improves_previous_best': False,
#  'minimum_output': -0.06562362443733738,
#  'mean_output': 0.14425326972508104,
#  'standard_deviation': 0.18231470843195774,
#  'evidence_gap': 'No verified Week 12 or Week 13 return is present; confirmed cumulative evidence is available through Week 11.',
#  'interpretation': 'Within-function descriptive evidence; no causal or cross-function ranking claim.',
#  'archive_integrity': 'Original repository Week 11 arrays remain quarantined; analysis uses independently recovered pairs from the canonical ledger.'}

# %%
observations
# Out:
#     query  evidence        x1        x2  objective
# 0       1   starter  0.665800  0.123969   0.538996
# 1       2   starter  0.877791  0.778628   0.420586
# 2       3   starter  0.142699  0.349005  -0.065624
# 3       4   starter  0.845275  0.711120   0.293993
# 4       5   starter  0.454647  0.290455   0.214965
# 5       6   starter  0.577713  0.771973   0.023106
# 6       7   starter  0.438166  0.685018   0.244619
# 7       8   starter  0.341750  0.028698   0.038749
# 8       9   starter  0.338648  0.213867  -0.013858
# 9      10   starter  0.702637  0.926564   0.611205
# 10     11  recorded  0.374540  0.950714  -0.031830
# 11     12  recorded  0.978752  0.932731   0.022667
# 12     13  recorded  0.000006  0.334143   0.048684
# 13     14  recorded  0.197553  0.808683   0.038775
# 14     15  recorded  0.555332  0.360931   0.220781
# 15     16  recorded  0.473151  0.950706   0.160532
# 16     17  recorded  0.009675  0.999881   0.048714
# 17     18  recorded  0.314242  0.973527   0.072764
# 18     19  recorded  0.995366  0.102732   0.049406
# 19     20  recorded  0.329121  0.997950   0.026788
# 20     21  recorded  0.384537  0.996119   0.065300

# %%
figure

# %%
assert observations.shape[0]==summary['total_verified_observations']
assert observations.filter(regex=r'^x').to_numpy().min()>=0
assert observations.filter(regex=r'^x').to_numpy().max()<=1
assert observations['objective'].notna().all()
print('All Week 13 Function 02 checks passed.')
# Out:
# All Week 13 Function 02 checks passed.

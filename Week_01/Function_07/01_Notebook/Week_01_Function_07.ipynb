# %% [markdown]
# # Week 01 — Function 07
#
# Focused, reproducible review of the Bayesian Optimisation observations. Computation is imported from the standalone function module.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root = Path.cwd().resolve()
while not (repo_root / 'Code').exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent
function_root = repo_root / 'Week_01' / 'Function_07'
sys.path.insert(0, str(function_root / '02_Code'))
from analyse_function_07 import analyse_function_07, create_figure

# %%
observations, summary = analyse_function_07()
summary
# Out:
# {'function': '07',
#  'strategy': 'Bayesian Optimisation',
#  'n_observations': 30,
#  'n_dimensions': 6,
#  'best_query': 7,
#  'best_input': [0.057895541971385245,
#   0.49167221863901367,
#   0.24742222374867484,
#   0.21811843639837636,
#   0.42042832954601583,
#   0.7309698428701273],
#  'best_output': 1.3649683044991994,
#  'minimum_output': 0.0027014650245082332,
#  'mean_output': 0.21960657602342604,
#  'standard_deviation': 0.3021294180712925,
#  'submitted_query': [0.045091,
#   0.528666,
#   0.329265,
#   0.10535,
#   0.434667,
#   0.641164],
#  'submitted_return': 1.0510148516295004,
#  'submitted_improves_starter_best': False,
#  'submitted_improvement': -0.313953452869699}

# %%
observations
# Out:
#     query        x1        x2        x3        x4        x5        x6  \
# 0       1  0.272624  0.324495  0.897109  0.832951  0.154063  0.795864
# 1       2  0.543003  0.924694  0.341567  0.646486  0.718440  0.343133
# 2       3  0.090832  0.661529  0.065931  0.258577  0.963453  0.640265
# 3       4  0.118867  0.615055  0.905816  0.855300  0.413631  0.585236
# 4       5  0.630218  0.838097  0.680013  0.731895  0.526737  0.348429
# 5       6  0.764919  0.255883  0.609084  0.218079  0.322943  0.095794
# 6       7  0.057896  0.491672  0.247422  0.218118  0.420428  0.730970
# 7       8  0.195252  0.079227  0.554580  0.170567  0.014944  0.107032
# 8       9  0.642303  0.836875  0.021793  0.101488  0.683071  0.692416
# 9      10  0.789943  0.195545  0.575623  0.073659  0.259049  0.051100
# 10     11  0.528497  0.457424  0.360096  0.362046  0.816891  0.637476
# 11     12  0.722615  0.011813  0.063646  0.165173  0.079244  0.359952
# 12     13  0.075665  0.334502  0.132733  0.608312  0.918386  0.822331
# 13     14  0.942451  0.377440  0.486122  0.228791  0.082632  0.711958
# 14     15  0.148647  0.033943  0.728806  0.316066  0.021769  0.516918
# 15     16  0.817112  0.548168  0.103348  0.124370  0.728235  0.449674
# 16     17  0.417626  0.064100  0.245669  0.559041  0.191531  0.254641
# 17     18  0.726286  0.464896  0.924571  0.807245  0.635438  0.143418
# 18     19  0.319810  0.520098  0.290678  0.876707  0.495035  0.619082
# 19     20  0.879871  0.397962  0.003635  0.956991  0.264514  0.114869
# 20     21  0.541241  0.631403  0.031902  0.449982  0.798653  0.633704
# 21     22  0.226348  0.115026  0.824750  0.945384  0.905312  0.951014
# 22     23  0.686853  0.041017  0.007573  0.285009  0.691568  0.655543
# 23     24  0.175978  0.624416  0.295542  0.469553  0.097770  0.728141
# 24     25  0.881647  0.204450  0.414474  0.420385  0.264915  0.730660
# 25     26  0.066611  0.528045  0.816095  0.961017  0.086509  0.777788
# 26     27  0.932466  0.488812  0.258608  0.956243  0.190428  0.519852
# 27     28  0.846867  0.142429  0.060669  0.756292  0.552398  0.081306
# 28     29  0.806282  0.324122  0.726076  0.148712  0.719376  0.362884
# 29     30  0.476823  0.340942  0.014335  0.880140  0.998655  0.079664
#
#     objective
# 0    0.604433
# 1    0.562753
# 2    0.007503
# 3    0.061424
# 4    0.273047
# 5    0.083747
# 6    1.364968
# 7    0.092645
# 8    0.017870
# 9    0.033565
# 10   0.073516
# 11   0.206310
# 12   0.008826
# 13   0.268400
# 14   0.611526
# 15   0.014798
# 16   0.274893
# 17   0.066763
# 18   0.042118
# 19   0.002701
# 20   0.018209
# 21   0.007016
# 22   0.100507
# 23   0.475396
# 24   0.675142
# 25   0.516457
# 26   0.003777
# 27   0.003134
# 28   0.021343
# 29   0.095411

# %%
figure = create_figure(observations, summary)
plt.show()

# %%
assert observations.shape == (summary['n_observations'], summary['n_dimensions'] + 2)
assert observations.filter(regex=r'^x').to_numpy().min() >= 0
assert observations.filter(regex=r'^x').to_numpy().max() <= 1
assert observations['objective'].notna().all()
print('All Function 07 checks passed.')
# Out:
# All Function 07 checks passed.

# %% [markdown]
# <a href="https://colab.research.google.com/github/JPAmewu/My_Capstone_1_Imperial/blob/main/Week_1_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir("initial_data_1"))
# Out:
# ['function_4', 'function_5', 'function_3', 'function_8', 'function_7', 'function_2', 'function_1', 'function_6']

# %%
import os

for item in os.listdir("initial_data_1"):
    print(item)
# Out:
# function_4
# function_5
# function_3
# function_8
# function_7
# function_2
# function_1
# function_6

# %%
import os

folders = sorted(os.listdir("initial_data_1"))

for i, folder in enumerate(folders, start=1):
    print(f"{i}. {folder}")
# Out:
# 1. function_1
# 2. function_2
# 3. function_3
# 4. function_4
# 5. function_5
# 6. function_6
# 7. function_7
# 8. function_8

# %%
import os

for i in range(1, 9):
    print(f"\nFunction {i}")
    print(sorted(os.listdir(f"initial_data_1/function_{i}")))
# Out:
# Function 1
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 2
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 3
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 4
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 5
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 6
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 7
# ['initial_inputs.npy', 'initial_outputs.npy']
#
# Function 8
# ['initial_inputs.npy', 'initial_outputs.npy']

# %%
# Examine the shape of the Functions

import numpy as np

for i in range(1, 9):
    X = np.load(f"initial_data_1/function_{i}/initial_inputs.npy")
    y = np.load(f"initial_data_1/function_{i}/initial_outputs.npy")

    print(f"\nFunction {i}")
    print("X shape:", X.shape)
    print("y shape:", y.shape)
# Out:
# Function 1
# X shape: (10, 2)
# y shape: (10,)
#
# Function 2
# X shape: (10, 2)
# y shape: (10,)
#
# Function 3
# X shape: (15, 3)
# y shape: (15,)
#
# Function 4
# X shape: (30, 4)
# y shape: (30,)
#
# Function 5
# X shape: (20, 4)
# y shape: (20,)
#
# Function 6
# X shape: (20, 5)
# y shape: (20,)
#
# Function 7
# X shape: (30, 6)
# y shape: (30,)
#
# Function 8
# X shape: (40, 8)
# y shape: (40,)

# %%
# Print the inputs and the outputs

import numpy as np

for i in range(1,9):

    X = np.load(f"initial_data_1/function_{i}/initial_inputs.npy")
    y = np.load(f"initial_data_1/function_{i}/initial_outputs.npy")

    print(f"\n{'='*50}")
    print(f"FUNCTION {i}")
    print(f"{'='*50}")

    print("Inputs:")
    print(X[:5])

    print("\nOutputs:")
    print(y[:5])
# Out:
# ...
# FUNCTION 1
# ...
# Inputs:
# [[0.31940389 0.76295937]
#  [0.57432921 0.8798981 ]
#  [0.73102363 0.73299988]
#  [0.84035342 0.26473161]
#  [0.65011406 0.68152635]]
#
# Outputs:
# [ 1.32267704e-079  1.03307824e-046  7.71087511e-016  3.34177101e-124
#  -3.60606264e-003]
#
# ...
# FUNCTION 2
# ...
# Inputs:
# [[0.66579958 0.12396913]
#  [0.87779099 0.7786275 ]
#  [0.14269907 0.34900513]
#  [0.84527543 0.71112027]
#  [0.45464714 0.29045518]]
#
# Outputs:
# [ 0.53899612  0.42058624 -0.06562362  0.29399291  0.21496451]
#
# ...
# FUNCTION 3
# ...
# Inputs:
# [[0.17152521 0.34391687 0.2487372 ]
#  [0.24211446 0.64407427 0.27243281]
#  [0.53490572 0.39850092 0.17338873]
#  [0.49258141 0.61159319 0.34017639]
#  [0.13462167 0.21991724 0.45820622]]
#
# Outputs:
# [-0.1121222  -0.08796286 -0.11141465 -0.03483531 -0.04800758]
#
# ...
# FUNCTION 4
# ...
# Inputs:
# [[0.89698105 0.72562797 0.17540431 0.70169437]
#  [0.8893564  0.49958786 0.53926886 0.50878344]
#  [0.25094624 0.03369313 0.14538002 0.49493242]
# ...

# %%
# Strategy used for each function in Week 1

import numpy as np

strategy = {
    1: "Random Search",
    2: "Random Search",
    3: "Grid Search",
    4: "Grid Search",
    5: "Manual Reasoning",
    6: "Manual Reasoning",
    7: "Bayesian Optimisation",
    8: "Bayesian Optimisation"
}

for i in range(1, 9):

    X = np.load(f"initial_data_1/function_{i}/initial_inputs.npy")
    y = np.load(f"initial_data_1/function_{i}/initial_outputs.npy")

    best_idx = np.argmax(y)

    print("\n" + "="*60)
    print(f"FUNCTION {i}")
    print(f"Strategy: {strategy[i]}")
    print("="*60)

    print("Number of Queries:", len(y))
    print("Best Output:", y[best_idx])
    print("Best Input Point:")
    print(X[best_idx])
# Out:
# ...
# FUNCTION 1
# Strategy: Random Search
# ...
# Number of Queries: 10
# Best Output: 7.710875114502849e-16
# Best Input Point:
# [0.73102363 0.73299988]
#
# ...
# FUNCTION 2
# Strategy: Random Search
# ...
# Number of Queries: 10
# Best Output: 0.6112052157614438
# Best Input Point:
# [0.70263656 0.9265642 ]
#
# ...
# FUNCTION 3
# Strategy: Grid Search
# ...
# Number of Queries: 15
# Best Output: -0.034835313350078584
# Best Input Point:
# [0.49258141 0.61159319 0.34017639]
#
# ...
# FUNCTION 4
# Strategy: Grid Search
# ...
# Number of Queries: 30
# Best Output: -4.025542281908162
# Best Input Point:
# [0.57776561 0.42877174 0.42582587 0.24900741]
#
# ...
# FUNCTION 5
# Strategy: Manual Reasoning
# ...
# Number of Queries: 20
# Best Output: 1088.8596181962705
# Best Input Point:
# [0.22418902 0.84648049 0.87948418 0.87851568]
#
# ...
# FUNCTION 6
# Strategy: Manual Reasoning
# ...
# Number of Queries: 20
# Best Output: -0.7142649478202404
# Best Input Point:
# [0.7281861  0.15469257 0.73255167 0.69399651 0.05640131]
#
# ...
# FUNCTION 7
# ...

# %%
# Find Average Technique Output

import numpy as np

strategy_groups = {
    "Random Search": [1, 2],
    "Grid Search": [3, 4],
    "Manual Reasoning": [5, 6],
    "Bayesian Optimisation": [7, 8]
}

for strategy, funcs in strategy_groups.items():

    best_outputs = []

    for i in funcs:

        y = np.load(
            f"initial_data_1/function_{i}/initial_outputs.npy"
        )

        best_outputs.append(np.max(y))

    avg_best = np.mean(best_outputs)

    print(f"\n{strategy}")
    print("Functions:", funcs)
    print("Best Outputs:", best_outputs)
    print("Average Best Output:", avg_best)
# Out:
# Random Search
# Functions: [1, 2]
# Best Outputs: [np.float64(7.710875114502849e-16), np.float64(0.6112052157614438)]
# Average Best Output: 0.3056026078807223
#
# Grid Search
# Functions: [3, 4]
# Best Outputs: [np.float64(-0.034835313350078584), np.float64(-4.025542281908162)]
# Average Best Output: -2.0301887976291204
#
# Manual Reasoning
# Functions: [5, 6]
# Best Outputs: [np.float64(1088.8596181962705), np.float64(-0.7142649478202404)]
# Average Best Output: 544.0726766242251
#
# Bayesian Optimisation
# Functions: [7, 8]
# Best Outputs: [np.float64(1.3649683044991994), np.float64(9.598482002566342)]
# Average Best Output: 5.481725153532771

# %%
import numpy as np
import matplotlib.pyplot as plt

for i in range(1, 9):

    X = np.load(f"initial_data_1/function_{i}/initial_inputs.npy")
    y = np.load(f"initial_data_1/function_{i}/initial_outputs.npy")

    best_idx = np.argmax(y)

    query_numbers = np.arange(1, len(y) + 1)

    plt.figure(figsize=(8, 5))

    plt.plot(query_numbers, y, marker="o")
    plt.scatter(query_numbers[best_idx], y[best_idx], s=120)

    plt.title(f"Function {i}: Query Outputs")
    plt.xlabel("Query Number")
    plt.ylabel("Output Value")

    plt.grid(True)
    plt.show()

    print(f"Function {i}")
    print("Best Query Number:", best_idx + 1)
    print("Best Query Point:", X[best_idx])
    print("Best Output:", y[best_idx])
    print("-" * 60)
# Out:
# Function 1
# Best Query Number: 3
# Best Query Point: [0.73102363 0.73299988]
# Best Output: 7.710875114502849e-16
# ------------------------------------------------------------
# Function 2
# Best Query Number: 10
# Best Query Point: [0.70263656 0.9265642 ]
# Best Output: 0.6112052157614438
# ------------------------------------------------------------
# Function 3
# Best Query Number: 4
# Best Query Point: [0.49258141 0.61159319 0.34017639]
# Best Output: -0.034835313350078584
# ------------------------------------------------------------
# Function 4
# Best Query Number: 28
# Best Query Point: [0.57776561 0.42877174 0.42582587 0.24900741]
# Best Output: -4.025542281908162
# ------------------------------------------------------------
# Function 5
# Best Query Number: 16
# Best Query Point: [0.22418902 0.84648049 0.87948418 0.87851568]
# Best Output: 1088.8596181962705
# ------------------------------------------------------------
# Function 6
# Best Query Number: 1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

for i in range(1, 9):

    X = np.load(f"initial_data_1/function_{i}/initial_inputs.npy")
    y = np.load(f"initial_data_1/function_{i}/initial_outputs.npy")

    n_features = X.shape[1]

    print(f"\nFUNCTION {i}")
    print(f"Dimensions: {n_features}")

    plt.figure(figsize=(5*n_features,4))

    for j in range(n_features):

        plt.subplot(1, n_features, j+1)

        plt.scatter(X[:,j], y)

        plt.xlabel(f"x{j+1}")
        plt.ylabel("Output (y)")
        plt.title(f"x{j+1} vs y")

        plt.grid(True)

    plt.tight_layout()
    plt.show()
# Out:
# FUNCTION 1
# Dimensions: 2
# FUNCTION 2
# Dimensions: 2
# FUNCTION 3
# Dimensions: 3
# FUNCTION 4
# Dimensions: 4
# FUNCTION 5
# Dimensions: 4
# FUNCTION 6
# Dimensions: 5
# FUNCTION 7
# Dimensions: 6
# FUNCTION 8
# Dimensions: 8

# %% [markdown]
# # Week 01 — Function 01
#
# This focused notebook validates and analyses the canonical Function 1 starter data. The main eight-function analysis remains in `Week_01/02_Notebook/Week_1_Capstone.ipynb`.

# %%
from pathlib import Path
import sys

current = Path.cwd().resolve()
REPO_ROOT = next(path for path in (current, *current.parents) if (path / 'Week_01').is_dir() and (path / 'Code').is_dir())
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

CODE_DIR = REPO_ROOT / 'Week_01' / 'Function_01' / '02_Code'
if str(CODE_DIR) not in sys.path:
    sys.path.insert(0, str(CODE_DIR))
from analyse_function_01 import analyse_function_01
observations, summary, figure = analyse_function_01(REPO_ROOT)
summary
# Out:
# {'observations': 10,
#  'dimensions': 2,
#  'best_index': 2,
#  'best_query_number': 3,
#  'best_input': array([0.73102363, 0.73299988]),
#  'best_output': 7.710875114502849e-16,
#  'latest_output': 6.229856468168659e-48,
#  'latest_percentile': 70.0,
#  'input_min': array([0.08250725, 0.07872278]),
#  'input_max': array([0.88388983, 0.8798981 ]),
#  'function': 'F1',
#  'week': 1,
#  'strategy': 'Random Search'}

# %%
observations
# Out:
#          x1        x2         output  query  running_best
# 0  0.319404  0.762959   1.322677e-79      1  1.322677e-79
# 1  0.574329  0.879898   1.033078e-46      2  1.033078e-46
# 2  0.731024  0.733000   7.710875e-16      3  7.710875e-16
# 3  0.840353  0.264732  3.341771e-124      4  7.710875e-16
# 4  0.650114  0.681526  -3.606063e-03      5  7.710875e-16
# 5  0.410437  0.147554  -2.159249e-54      6  7.710875e-16
# 6  0.312691  0.078723  -2.089093e-91      7  7.710875e-16
# 7  0.683418  0.861057   2.535001e-40      8  7.710875e-16
# 8  0.082507  0.403488   3.606771e-81      9  7.710875e-16
# 9  0.883890  0.582254   6.229856e-48     10  7.710875e-16

# %%
figure

# %% [markdown]
# ## Reproducibility checks

# %%
assert summary['observations'] == 10
assert summary['dimensions'] == 2
assert summary['best_query_number'] == 3
assert observations.shape == (10, 5)
assert observations['running_best'].is_monotonic_increasing
print('All Week 1 Function 1 checks passed.')
# Out:
# All Week 1 Function 1 checks passed.

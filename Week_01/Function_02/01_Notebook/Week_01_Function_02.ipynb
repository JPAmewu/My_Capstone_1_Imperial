# %% [markdown]
# # Week 01 — Function 02
#
# Focused, reproducible review of the Random Search observations. Computation is imported from the standalone function module.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root = Path.cwd().resolve()
while not (repo_root / 'Code').exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent
function_root = repo_root / 'Week_01' / 'Function_02'
sys.path.insert(0, str(function_root / '02_Code'))
from analyse_function_02 import analyse_function_02, create_figure

# %%
observations, summary = analyse_function_02()
summary
# Out:
# {'function': '02',
#  'strategy': 'Random Search',
#  'n_observations': 10,
#  'n_dimensions': 2,
#  'best_query': 10,
#  'best_input': [0.7026365569244406, 0.9265641975455574],
#  'best_output': 0.6112052157614438,
#  'minimum_output': -0.06562362443733738,
#  'mean_output': 0.23067376631994235,
#  'standard_deviation': 0.22536450367310826,
#  'submitted_query': [0.37544, 0.950714],
#  'submitted_return': -0.03182956281754251,
#  'submitted_improves_starter_best': False,
#  'submitted_improvement': -0.6430347785789863}

# %%
observations
# Out:
#    query        x1        x2  objective
# 0      1  0.665800  0.123969   0.538996
# 1      2  0.877791  0.778628   0.420586
# 2      3  0.142699  0.349005  -0.065624
# 3      4  0.845275  0.711120   0.293993
# 4      5  0.454647  0.290455   0.214965
# 5      6  0.577713  0.771973   0.023106
# 6      7  0.438166  0.685018   0.244619
# 7      8  0.341750  0.028698   0.038749
# 8      9  0.338648  0.213867  -0.013858
# 9     10  0.702637  0.926564   0.611205

# %%
figure = create_figure(observations, summary)
plt.show()

# %%
assert observations.shape == (summary['n_observations'], summary['n_dimensions'] + 2)
assert observations.filter(regex=r'^x').to_numpy().min() >= 0
assert observations.filter(regex=r'^x').to_numpy().max() <= 1
assert observations['objective'].notna().all()
print('All Function 02 checks passed.')
# Out:
# All Function 02 checks passed.

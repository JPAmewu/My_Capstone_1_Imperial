# %% [markdown]
# # Week 01 — Function 02
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [GP model configuration](#gp-model-configuration)
# 9. [GP-UCB values](#gp-ucb-values)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused notebook mirrors the authoritative Week 1 main notebook for Function 02. It analyses the ten immutable starter observations as a model-free random-search baseline.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the two-dimensional starter dataset, report its descriptive baseline, and preserve a reproducible starting point for later optimisation rounds.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# The authoritative Week 1 inputs are `initial_inputs.npy` and `initial_outputs.npy`. The ledger-derived Week 1 return is later cumulative evidence and is deliberately excluded from this starter-baseline analysis. No proposal is promoted to an observation here.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup
#
# Locate the repository and import the stable Function 02 analysis interface.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd().resolve()
for candidate in (ROOT, *ROOT.parents):
    if (candidate / 'Week_01' / 'Function_02').is_dir(): ROOT = candidate; break
else: raise FileNotFoundError('Could not locate the repository root.')
CODE_DIR = ROOT / 'Week_01/Function_02/02_Code'
if str(CODE_DIR) not in sys.path: sys.path.insert(0, str(CODE_DIR))
from analyse_function_02 import analyse_function_02

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation
#
# Load the ten starter rows and validate alignment, dimensionality, finiteness, and unit-square bounds.

# %%
observations, summary, diagnostic_figure = analyse_function_02(ROOT)
inputs = observations[['x1', 'x2']].to_numpy(float)
outputs = observations['output'].to_numpy(float)
assert inputs.shape == (10, 2) and outputs.shape == (10,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs >= 0) & (inputs <= 1))
pd.DataFrame({'measure':['input shape','output shape','missing values','out-of-bounds inputs'],'value':[str(inputs.shape),str(outputs.shape),int(np.isnan(inputs).sum()+np.isnan(outputs).sum()),int(((inputs<0)|(inputs>1)).sum())]})
# Out:
#                 measure    value
# 0           input shape  (10, 2)
# 1          output shape    (10,)
# 2        missing values        0
# 3  out-of-bounds inputs        0

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# Function 02 is assessed only in its own objective scale. The maximum is an observed incumbent, not a global optimum.

# %%
display(observations)
pd.Series(summary, name='Function 02 baseline')
# Out:
#          x1        x2    output  query  running_best
# 0  0.665800  0.123969  0.538996      1      0.538996
# 1  0.877791  0.778628  0.420586      2      0.538996
# 2  0.142699  0.349005 -0.065624      3      0.538996
# 3  0.845275  0.711120  0.293993      4      0.538996
# 4  0.454647  0.290455  0.214965      5      0.538996
# 5  0.577713  0.771973  0.023106      6      0.538996
# 6  0.438166  0.685018  0.244619      7      0.538996
# 7  0.341750  0.028698  0.038749      8      0.538996
# 8  0.338648  0.213867 -0.013858      9      0.538996
# 9  0.702637  0.926564  0.611205     10      0.611205
# observations                                                  10
# dimensions                                                     2
# best_index                                                     9
# best_query_number                                             10
# best_input              [0.7026365569244406, 0.9265641975455574]
# best_output                                             0.611205
# latest_output                                           0.611205
# latest_percentile                                          100.0
# input_min            [0.14269907423594608, 0.028697719822277867]
# input_max               [0.8777909889953304, 0.9265641975455574]
# function                                                      F2
# week                                                           1
# strategy                                           Random Search
# Name: Function 02 baseline, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Show the observation trace, running best, and both input/output relationships.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="gp-model-configuration"></a>
# ## 8. GP model configuration
#
# Week 1 establishes the model-free baseline; Gaussian Process configuration is introduced in later rounds.

# %% [markdown]
# <a id="gp-ucb-values"></a>
# ## 9. GP-UCB values
#
# No GP-UCB proposal is claimed for the Week 1 baseline. The ten starter values remain the authoritative evidence for this analysis.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks
#
# Confirm the starter count, best row, and exact agreement with the Function 02 summary.

# %%
best_index = int(np.argmax(outputs))
assert summary['observations'] == 10 and summary['dimensions'] == 2
assert summary['best_query_number'] == best_index + 1 == 10
assert np.isclose(summary['best_output'], outputs[best_index])
assert np.allclose(summary['best_input'], inputs[best_index])
print('Function 02 Week 1 baseline checks passed.')
# Out:
# Function 02 Week 1 baseline checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The ten starter observations establish a reproducible random-search baseline. Query 10 is the observed incumbent at `0.6112052`; later returned evidence belongs to the sequential ledger and later checkpoints.

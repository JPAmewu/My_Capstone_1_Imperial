# %% [markdown]
# # Week 01 — Function 04
#
# ## Table of contents
#
# 1. [Overview](#overview)
# 2. [Objectives](#objectives)
# 3. [Evidence provenance](#evidence-provenance)
# 4. [Environment and setup](#environment-setup)
# 5. [Data validation](#data-validation)
# 6. [Descriptive EDA](#descriptive-eda)
# 7. [Visual EDA](#visual-eda)
# 8. [GP model configuration](#gp-model-configuration)
# 9. [GP-UCB values](#gp-ucb-values)
# 10. [Reproducibility checks](#reproducibility-checks)
# 11. [Conclusions and next steps](#conclusions-next-steps)

# %% [markdown]
# <a id="overview"></a>
# ## 1. Overview
#
# This focused notebook mirrors the authoritative Week 1 main notebook for Function 04. It analyses the 30 immutable starter observations as a model-free Grid Search baseline.

# %% [markdown]
# <a id="objectives"></a>
# ## 2. Objectives
#
# Validate the four-dimensional starter dataset, report its descriptive baseline, and preserve a reproducible starting point for later optimisation rounds.

# %% [markdown]
# <a id="evidence-provenance"></a>
# ## 3. Evidence provenance
#
# The authoritative Week 1 inputs are `initial_inputs.npy` and `initial_outputs.npy`. The ledger-derived Week 1 return is later cumulative evidence and is deliberately excluded from this starter-baseline analysis. No proposal is promoted to an observation here.

# %% [markdown]
# <a id="environment-setup"></a>
# ## 4. Environment and setup
#
# Locate the repository and import the stable Function 04 analysis interface.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd().resolve()
for candidate in (ROOT, *ROOT.parents):
    if (candidate / 'Week_01' / 'Function_04').is_dir(): ROOT = candidate; break
else: raise FileNotFoundError('Could not locate the repository root.')
CODE_DIR = ROOT / 'Week_01/Function_04/02_Code'
if str(CODE_DIR) not in sys.path: sys.path.insert(0, str(CODE_DIR))
from analyse_function_04 import analyse_function_04

# %% [markdown]
# <a id="data-validation"></a>
# ## 5. Data validation
#
# Load the 30 starter rows and validate alignment, dimensionality, finiteness, and unit-cube bounds.

# %%
observations, summary, diagnostic_figure = analyse_function_04(ROOT)
inputs = observations[['x1', 'x2', 'x3', 'x4']].to_numpy(float)
outputs = observations['output'].to_numpy(float)
assert inputs.shape == (30, 4) and outputs.shape == (30,)
assert np.isfinite(inputs).all() and np.isfinite(outputs).all()
assert np.all((inputs >= 0) & (inputs <= 1))
pd.DataFrame({'measure':['input shape','output shape','missing values','out-of-bounds inputs'],'value':[str(inputs.shape),str(outputs.shape),int(np.isnan(inputs).sum()+np.isnan(outputs).sum()),int(((inputs<0)|(inputs>1)).sum())]})
# Out:
#                 measure    value
# 0           input shape  (30, 4)
# 1          output shape    (30,)
# 2        missing values        0
# 3  out-of-bounds inputs        0

# %% [markdown]
# <a id="descriptive-eda"></a>
# ## 6. Descriptive EDA
#
# Function 04 is assessed only in its own objective scale. Its negative maximum is valid: the least-negative observed value is the incumbent, not a global optimum.

# %%
display(observations)
pd.Series(summary, name='Function 04 baseline')
# Out:
#           x1        x2        x3        x4     output  query  running_best
# 0   0.896981  0.725628  0.175404  0.701694 -22.108288      1    -22.108288
# 1   0.889356  0.499588  0.539269  0.508783 -14.601397      2    -14.601397
# 2   0.250946  0.033693  0.145380  0.494932 -11.699932      3    -11.699932
# 3   0.346962  0.006250  0.760564  0.613024 -16.053765      4    -11.699932
# 4   0.124871  0.129770  0.384400  0.287076 -10.069633      5    -10.069633
# 5   0.801303  0.500231  0.706645  0.195103 -15.487083      6    -10.069633
# 6   0.247708  0.060445  0.042186  0.441324 -12.681685      7    -10.069633
# 7   0.746702  0.757092  0.369353  0.206566 -16.026400      8    -10.069633
# 8   0.400665  0.072574  0.886768  0.243842 -17.049235      9    -10.069633
# 9   0.626071  0.586751  0.438806  0.778858 -12.741766     10    -10.069633
# 10  0.957135  0.597644  0.766114  0.776210 -27.316396     11    -10.069633
# 11  0.732812  0.145250  0.476813  0.133366 -13.527649     12    -10.069633
# 12  0.655115  0.072392  0.687152  0.081517 -16.679115     13    -10.069633
# 13  0.219734  0.832031  0.482864  0.082569 -16.507159     14    -10.069633
# 14  0.488594  0.211965  0.939178  0.376192 -17.817999     15    -10.069633
# 15  0.167130  0.876555  0.217240  0.959801 -26.561821     16    -10.069633
# 16  0.216911  0.166086  0.241372  0.770062 -12.758324     17    -10.069633
# 17  0.387488  0.804532  0.751795  0.723827 -19.441558     18    -10.069633
# 18  0.985622  0.666933  0.156783  0.856535 -28.903274     19    -10.069633
# 19  0.037825  0.664853  0.161982  0.253924 -13.702747     20    -10.069633
# 20  0.683486  0.902770  0.335420  0.999483 -29.427091     21    -10.069633
# 21  0.170347  0.756959  0.276520  0.531231 -11.565742     22    -10.069633
# 22  0.859657  0.919592  0.206139  0.097797 -26.857786     23    -10.069633
# 23  0.282138  0.505987  0.530531  0.096302  -7.966775     24     -7.966775
# 24  0.326076  0.472367  0.453192  0.105887  -6.702089     25     -6.702089
# 25  0.948389  0.894513  0.851638  0.552196 -32.625660     26     -6.702089
# 26  0.664955  0.046566  0.116777  0.793718 -19.989498     27     -6.702089
# 27  0.577766  0.428772  0.425826  0.249007  -4.025542     28     -4.025542
# 28  0.738613  0.482103  0.709366  0.503970 -13.122782     29     -4.025542
# 29  0.854811  0.493965  0.735310  0.808092 -23.139428     30     -4.025542
# observations                                                        30
# dimensions                                                           4
# best_index                                                          27
# best_query_number                                                   28
# best_input           [0.5777656143780968, 0.4287717415443063, 0.425...
# best_output                                                  -4.025542
# latest_output                                               -23.139428
# latest_percentile                                            23.333333
# input_min            [0.03782482853334601, 0.006250400244917853, 0....
# input_max            [0.9856218929694016, 0.9195923219593923, 0.939...
# function                                                            F4
# week                                                                 1
# strategy                                                   Grid Search
# Name: Function 04 baseline, dtype: object

# %% [markdown]
# <a id="visual-eda"></a>
# ## 7. Visual EDA
#
# Show the observation trace, running best, and all four input/output relationships.

# %%
display(diagnostic_figure)
plt.close(diagnostic_figure)

# %% [markdown]
# <a id="gp-model-configuration"></a>
# ## 8. GP model configuration
#
# Week 1 establishes the model-free baseline; Gaussian Process configuration is introduced in later rounds.

# %% [markdown]
# <a id="gp-ucb-values"></a>
# ## 9. GP-UCB values
#
# No GP-UCB proposal is claimed for the Week 1 baseline. The 30 starter values remain the authoritative evidence for this analysis.

# %% [markdown]
# <a id="reproducibility-checks"></a>
# ## 10. Reproducibility checks
#
# Confirm the starter count, best row, and exact agreement with the Function 04 summary.

# %%
best_index = int(np.argmax(outputs))
assert summary['observations'] == 30 and summary['dimensions'] == 4
assert summary['best_query_number'] == best_index + 1 == 28
assert np.isclose(summary['best_output'], outputs[best_index])
assert np.allclose(summary['best_input'], inputs[best_index])
print('Function 04 Week 1 baseline checks passed.')
# Out:
# Function 04 Week 1 baseline checks passed.

# %% [markdown]
# <a id="conclusions-next-steps"></a>
# ## 11. Conclusions and next steps
#
# The 30 starter observations establish a reproducible Grid Search baseline. Query 28 is the observed incumbent at `-4.02554228191`; later returned evidence belongs to the sequential ledger and later checkpoints.

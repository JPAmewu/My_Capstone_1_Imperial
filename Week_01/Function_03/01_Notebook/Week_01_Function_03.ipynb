# %% [markdown]
# # Week 01 — Function 03
#
# Focused, reproducible review of the Grid Search observations. Computation is imported from the standalone function module.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
repo_root = Path.cwd().resolve()
while not (repo_root / 'Code').exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent
function_root = repo_root / 'Week_01' / 'Function_03'
sys.path.insert(0, str(function_root / '02_Code'))
from analyse_function_03 import analyse_function_03, create_figure

# %%
observations, summary = analyse_function_03()
summary
# Out:
# {'function': '03',
#  'strategy': 'Grid Search',
#  'n_observations': 15,
#  'n_dimensions': 3,
#  'best_query': 4,
#  'best_input': [0.49258141463713434, 0.6115931882759961, 0.3401763860035727],
#  'best_output': -0.034835313350078584,
#  'minimum_output': -0.3989255131463011,
#  'mean_output': -0.10716697472812112,
#  'standard_deviation': 0.08421399358525467,
#  'submitted_query': [0.444444, 0.666666, 0.333333],
#  'submitted_return': -0.04090761844901528,
#  'submitted_improves_starter_best': False,
#  'submitted_improvement': -0.006072305098936699}

# %%
observations
# Out:
#     query        x1        x2        x3  objective
# 0       1  0.171525  0.343917  0.248737  -0.112122
# 1       2  0.242114  0.644074  0.272433  -0.087963
# 2       3  0.534906  0.398501  0.173389  -0.111415
# 3       4  0.492581  0.611593  0.340176  -0.034835
# 4       5  0.134622  0.219917  0.458206  -0.048008
# 5       6  0.345523  0.941360  0.269363  -0.110621
# 6       7  0.151837  0.439991  0.990882  -0.398926
# 7       8  0.645503  0.397143  0.919771  -0.113869
# 8       9  0.746912  0.284196  0.226300  -0.131461
# 9      10  0.170477  0.697032  0.149169  -0.094190
# 10     11  0.220549  0.297825  0.343555  -0.046947
# 11     12  0.666014  0.671985  0.246295  -0.105965
# 12     13  0.046809  0.231360  0.770618  -0.118048
# 13     14  0.600097  0.725136  0.066089  -0.036378
# 14     15  0.965995  0.861120  0.566829  -0.056758

# %%
figure = create_figure(observations, summary)
plt.show()

# %%
assert observations.shape == (summary['n_observations'], summary['n_dimensions'] + 2)
assert observations.filter(regex=r'^x').to_numpy().min() >= 0
assert observations.filter(regex=r'^x').to_numpy().max() <= 1
assert observations['objective'].notna().all()
print('All Function 03 checks passed.')
# Out:
# All Function 03 checks passed.
